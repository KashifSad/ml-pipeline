# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/campusx-official/jupyter-masterclass/main/tweet_emotions.csv")
df.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %%
df.drop(columns=['tweet_id'],inplace=True)
df

# %%
final_df = df[df['sentiment'].isin(["happiness","sadness"])]
final_df.sample(5)
# Out:
#        sentiment                                            content
# 4177     sadness  @mgiraudofficial  i'd give anything to be ther...
# 14315    sadness  I love summer, but I oddly don't want this sch...
# 33825  happiness        Chatting with matt from mercy mercedes lol.
# 2560     sadness  i lost all my friends, i'm alone and sleepy..i...
# 29919  happiness         http://twitpic.com/4w6lf - BBQ time again.

# %%
final_df['sentiment'].replace({'happiness':1,'sadness':0},inplace=True)
final_df
# Out:
# C:\Users\MV\AppData\Local\Temp\ipykernel_15760\4006240405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['sentiment'].replace({'happiness':1,'sadness':0},inplace=True)
#        sentiment                                            content
# 1              0  Layin n bed with a headache  ughhhh...waitin o...
# 2              0                Funeral ceremony...gloomy friday...
# 6              0  I should be sleep, but im not! thinking about ...
# 8              0            @charviray Charlene my love. I miss you
# 9              0         @kelcouch I'm sorry  at least it's Friday?
# ...          ...                                                ...
# 39986          1  going to watch boy in the striped pj's hope i ...
# 39987          1  gave the bikes a thorough wash, degrease it an...
# 39988          1  had SUCH and AMAZING time last night, McFly we...
# 39994          1                      Succesfully following Tayla!!
# 39998          1  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
#
# [10374 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(final_df,test_size=0.2,random_state=42)

# %%
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_tweet(tweet):
    # Convert to lowercase
    tweet = tweet.lower()
    
    # Remove URLs
    tweet = re.sub(r'http\S+|www\S+|https\S+', '', tweet, flags=re.MULTILINE)
    
    # Remove punctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize
    tokens = word_tokenize(tweet)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    
    # Join tokens back into string
    preprocessed_tweet = ' '.join(lemmatized_tokens)
    
    return preprocessed_tweet

# Example usage
tweet = "Just received my new iPhone! #excited https://example.com"
preprocessed_tweet = preprocess_tweet(tweet)
print(preprocessed_tweet)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MV\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MV\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\MV\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# received new iphone excited

# %%
import re
import string
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_tweet(tweet):
    # Convert to lowercase
    tweet = tweet.lower()
    
    # Remove URLs
    tweet = re.sub(r'http\S+|www\S+|https\S+', '', tweet, flags=re.MULTILINE)
    
    # Remove punctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize
    tokens = word_tokenize(tweet)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    
    # Join tokens back into string
    preprocessed_tweet = ' '.join(lemmatized_tokens)
    
    return preprocessed_tweet

def normalize(df):
    df['processed_tweet'] = df['content'].apply(preprocess_tweet)
    return df

# Sample training dataframe
data = {
    'tweet': [
        "Just received my new iPhone! #excited https://example.com",
        "Feeling happy after a long day at work. #relaxed",
        "Can't believe it's already Friday! #weekendvibes"
    ],
    'label': [1, 0, 1]  # Example labels
}
# df = pd.DataFrame(data)

# Apply preprocessing and normalization
df = pd.read_csv("../data/raw/train.csv")
df = normalize(df)

# Show the processed dataframe
print(df)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MV\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MV\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\MV\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#       Unnamed: 0  sentiment  \
# 0          23531          0
# 1           8051          0
# 2          11499          0
# 3          31288          1
# 4          18561          0
# ...          ...        ...
# 8294       21697          1
# 8295       19445          0
# 8296       20216          1
# 8297        3258          0
# 8298       27810          0
#
#                                                 content  \
# 0     &quot;My problem isn't that I miss you... 'cau...
# 1     That's it? It's done already? This is one proo...
# 2     I am so hungry! And there is no food for me to...
# 3     Feet hurt...finally in bed...will not forget t...
# 4                                        really ill atm
# ...                                                 ...
# 8294  @chocolatesuze yes yes you should! Especially ...
# 8295  @kickzfadayz Our boy better get it in tonight!...
# 8296             tafe was actually quite good. for once
# 8297  10 minutes to boarding; 14 hours to home. no w...
# 8298  Intel gfx driver situation much better with re...
#
#                                         processed_tweet
# 0               quotmy problem isnt miss cause dontquot
# 1     thats done already one proof there nothing fai...
# 2                                     hungry food steal
# 3     foot hurtfinally bedwill forget crunch overver...
# 4                                        really ill atm
# ...                                                 ...
# 8294  chocolatesuze yes yes especially wine mushroom...
# 8295                 kickzfadayz boy better get tonight
# 8296                           tafe actually quite good
# 8297        10 minute boarding 14 hour home window seat
# 8298  intel gfx driver situation much better recent ...
#
# [8299 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import CountVectorizer

training_features = pd.read_csv('./data/processed/train_processed.csv')
test_features = pd.read_csv('./data/processed/test_processed.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 6
#       3 import os
#       4 from sklearn.feature_extraction.text import CountVectorizer
# ----> 6 training_features = pd.read_csv('./data/processed/train_processed.csv')
#       7 test_features = pd.read_csv('./data/processed/test_processed.csv')
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/processed/train_processed.csv'

# %%
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pandas as pd
import numpy as np
import os

# fetch the data from raw folder
train_data = pd.read_csv('./data/raw/train.csv')
test_data = pd.read_csv('./data/raw/test.csv')

import re
import string
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_tweet(tweet):
    # Convert to lowercase
    tweet = tweet.lower()
    
    # Remove URLs
    tweet = re.sub(r'http\S+|www\S+|https\S+', '', tweet, flags=re.MULTILINE)
    
    # Remove punctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize
    tokens = word_tokenize(tweet)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    
    # Join tokens back into string
    preprocessed_tweet = ' '.join(lemmatized_tokens)
    
    return preprocessed_tweet

def normalize(df):
    df['processed_tweet'] = df['content'].apply(preprocess_tweet)
    return df

# Sample training dataframe
# data = {
#     'tweet': [
#         "Just received my new iPhone! #excited https://example.com",
#         "Feeling happy after a long day at work. #relaxed",
#         "Can't believe it's already Friday! #weekendvibes"
#     ],
#     'label': [1, 0, 1]  # Example labels
# }
# df = pd.DataFrame(data)

# Apply preprocessing and normalization
# df = normalize(df)

# Show the processed dataframe
# print(df)

train_processed_data = normalize(train_data)
test_processed_data = normalize(test_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 12
#       9 import os
#      11 # fetch the data from raw folder
# ---> 12 train_data = pd.read_csv('./data/raw/train.csv')
#      13 test_data = pd.read_csv('./data/raw/test.csv')
#      15 import re
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/raw/train.csv'

# %%
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import CountVectorizer

training_features = pd.read_csv('./data/raw/test.csv')
# test_features = pd.read_csv('./data/processed/test_processed.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 6
#       3 import os
#       4 from sklearn.feature_extraction.text import CountVectorizer
# ----> 6 training_features = pd.read_csv('./data/raw/test.csv')
#       7 # test_features = pd.read_csv('./data/processed/test_processed.csv')
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/raw/test.csv'

# %%
h = os.path.exists('c:\\Users\\MV\\Desktop\\ml-pipeline-demo\\data\\raw\\train.csv')
print(h)
os.getcwd()
# Out:
# True
# 'c:\\Users\\MV\\Desktop\\ml-pipeline-demo\\src'

# %%
pd.read_csv('c:\\Users\\MV\\Desktop\\ml-pipeline-demo\\data\\processed\\train_processed.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0  sentiment  \
# 0             0       23531          0
# 1             1        8051          0
# 2             2       11499          0
# 3             3       31288          1
# 4             4       18561          0
#
#                                              content  \
# 0  &quot;My problem isn't that I miss you... 'cau...
# 1  That's it? It's done already? This is one proo...
# 2  I am so hungry! And there is no food for me to...
# 3  Feet hurt...finally in bed...will not forget t...
# 4                                     really ill atm
#
#                                      processed_tweet
# 0            quotmy problem isnt miss cause dontquot
# 1  thats done already one proof there nothing fai...
# 2                                  hungry food steal
# 3  foot hurtfinally bedwill forget crunch overver...
# 4                                     really ill atm

# %%
test_features = pd.read_csv('c:\\Users\\MV\\Desktop\\ml-pipeline-demo\\data\\processed\\test_processed.csv')
test_features
# Out:
#       Unnamed: 0.1  Unnamed: 0  sentiment  \
# 0                0       11535          0
# 1                1       32287          0
# 2                2       17534          0
# 3                3        4696          0
# 4                4       23706          1
# ...            ...         ...        ...
# 2070          2070       38000          1
# 2071          2071        1540          0
# 2072          2072       38031          1
# 2073          2073       14702          0
# 2074          2074       22007          1
#
#                                                 content  \
# 0      looks like we're rained out for weekend climbing
# 1     Hi Everyone miss me much?  muahhhhhhhhhhhhhhhh...
# 2     rode the moped to the mall. fun stuff, its fli...
# 3     gutted!!! vodafone wont repair my faulty Samsu...
# 4                @shadowowns aww, &lt;3 why thank youu.
# ...                                                 ...
# 2070                          @russellburnham  nice one
# 2071  Tired. About to climb into bed and fall asleep...
# 2072  @Jadeyyg http://twitpic.com/4wrxq - whens your...
# 2073  @leirastorm  That's sucky. We'll miss you bein...
# 2074  I've got great expectations of tomorrow  It's ...
#
#                                         processed_tweet
# 0                     look like rained weekend climbing
# 1     hi everyone miss much muahhhhhhhhhhhhhhhhhhhhh...
# 2     rode moped mall fun stuff flippin gorgeous im ...
# 3     gutted vodafone wont repair faulty samsung omn...
# 4                         shadowowns aww lt3 thank youu
# ...                                                 ...
# 2070                            russellburnham nice one
# 2071  tired climb bed fall asleep hope weekend fun c...
# 2072     jadeyyg whens little gingg getting twitter g j
# 2073                   leirastorm thats sucky well miss
# 2074  ive got great expectation tomorrow gon na awesome
#
# [2075 rows x 5 columns]

# %%
train_data = pd.read_csv('./data/raw/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 train_data = pd.read_csv('./data/raw/train.csv')
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/raw/train.csv'

# %%
import pandas as pd
pd.read_csv('./data/raw/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 import pandas as pd
# ----> 2 pd.read_csv('./data/raw/train.csv')
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/raw/train.csv'
